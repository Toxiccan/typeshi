# %%
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]

# %%
import numpy as np

x = np.array([1, 2, 3, 4])
y = np.array([2, 4, 6, 8])

n = len(x)

w = 0.0
b = 0.0

learning_rate = 1
epochs = 1000

# %%
for epoch in range(epochs):
     y_hat = w*x + b
     error = y - y_hat

     dw = (-2/n)*np.sum(x * error)
     db = (-2/n)*np.sum(error)

     w = w - learning_rate * dw
     b = b - learning_rate * db

     loss = (1/n) * np.sum(error**2)

     if epoch % 100 == 0:
        print(f"Epoch {epoch},Loss: {loss:.4f}")
# Out:
# Epoch 0,Loss: 30.0000
# Epoch 100,Loss: 4565887906341295414016669454897531830820511105356404706795430861908623102062465849098380770547922993341314567008758284438833260903275946998312742996636511378942055462648419343841246322551576104817107274271828266939212404082474739787345428480.0000
# Epoch 200,Loss: inf
# Epoch 300,Loss: nan
# Epoch 400,Loss: nan
# Epoch 500,Loss: nan
# Epoch 600,Loss: nan
# Epoch 700,Loss: nan
# Epoch 800,Loss: nan
# Epoch 900,Loss: nan
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20440\2008147824.py:11: RuntimeWarning: overflow encountered in square
#   loss = (1/n) * np.sum(error**2)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20440\2008147824.py:5: RuntimeWarning: overflow encountered in multiply
#   dw = (-2/n)*np.sum(x * error)
# C:\Users\Admin\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20440\2008147824.py:8: RuntimeWarning: invalid value encountered in scalar subtract
#   w = w - learning_rate * dw
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20440\2008147824.py:9: RuntimeWarning: invalid value encountered in scalar subtract
#   b = b - learning_rate * db
